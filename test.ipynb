# %%
import pandas as pd

# %%
df = pd.read_csv('var11.csv')
df
# Out:
#       Участники гражданского оборота       Тип операции  Сумма операции  \
# 0                           юр. лицо  получение средств         3337.34
# 1                          физ. лицо   списание средств         3074.04
# 2                           юр. лицо   списание средств         4611.16
# 3                           юр. лицо  получение средств         4286.40
# 4                          физ. лицо  получение средств         2299.82
# ...                              ...                ...             ...
# 99995                      физ. лицо   списание средств          729.64
# 99996                       юр. лицо  получение средств         2613.11
# 99997                      физ. лицо  получение средств         3446.13
# 99998                       юр. лицо  получение средств          598.64
# 99999                      физ. лицо   списание средств         1922.73
#
#        Вид расчета Место оплаты           Терминал оплаты Дата оплаты  \
# ...

# %%
df1 = df.drop_duplicates()
df1
# Out:
#       Участники гражданского оборота       Тип операции  Сумма операции  \
# 0                           юр. лицо  получение средств         3337.34
# 1                          физ. лицо   списание средств         3074.04
# 2                           юр. лицо   списание средств         4611.16
# 3                           юр. лицо  получение средств         4286.40
# 4                          физ. лицо  получение средств         2299.82
# ...                              ...                ...             ...
# 99993                       юр. лицо  получение средств          261.25
# 99994                       юр. лицо  получение средств         3762.61
# 99995                      физ. лицо   списание средств          729.64
# 99996                       юр. лицо  получение средств         2613.11
# 99997                      физ. лицо  получение средств         3446.13
#
#        Вид расчета Место оплаты           Терминал оплаты Дата оплаты  \
# ...

# %%
df1 = pd.read_csv('second.csv')

print(df1['Время оплаты'].min())
# Out:
# nan
